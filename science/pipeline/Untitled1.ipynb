# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
import numpy as np
data = np.load('gc_124_acc.npy')
times = np.load('gc_124_time.npy')

# %%
data
# Out:
# array([1.99161498e-10, 1.99164407e-10, 1.99167318e-10, ...,
#        1.00000000e+00, 1.00000000e+00, 1.00000000e+00])

# %%
fig, ax = plt.subplots(dpi=200)
ax.plot(times[:-1], 10**data)
plt.show()
# Out:
# /lscratch/jaymarie/tmp/ipykernel_3406464/3616959450.py:2: RuntimeWarning: overflow encountered in power
#   ax.plot(times[:-1], 10**data)

# %%
np.nanmax(10**data)
# Out:
# /lscratch/jaymarie/tmp/ipykernel_3406464/174362416.py:1: RuntimeWarning: overflow encountered in power
#   np.nanmax(10**data)
# inf
